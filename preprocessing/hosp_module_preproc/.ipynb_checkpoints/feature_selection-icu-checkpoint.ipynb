# %%
import os
import pickle
os.chdir('../../')
from utils.hosp_preprocess_util import *    # module of preprocessing functions

# %%
# Custom function for preprocessing tables with ICD codes
# Takes a path to the diagnoses_icd table, a gzipped admissions-cohort table path, and an optional mapping table path
# Output shows codes that were unable to be mapped by the mapping table
diag = preproc_icd_module("./mimic-iv-1.0/hosp/diagnoses_icd.csv.gz", './data/cohort/cohort_non-icu_30_day_readmission.csv.gz', './utils/mappings/ICD9_to_ICD10_mapping.txt', map_code_colname='diagnosis_code')
diag[['subject_id', 'hadm_id', 'icd_code','root_icd10_convert','root']].to_csv("./data/features/preproc_diag.csv.gz", compression='gzip', index=False)
# Out:
# 100%|██████████| 9134/9134 [00:41<00:00, 222.18it/s]
# # unique ICD-9 codes 9134
# # unique ICD-10 codes 16924
# # unique ICD-10 codes (After converting ICD-9 to ICD-10) 17126
# # unique ICD-10 codes (After clinical gruping ICD-10 codes) 1695

# %%
proc = preproc_proc("./mimic-iv-1.0/hosp/procedures_icd.csv.gz", './data/cohort/cohort_non-icu_30_day_readmission.csv.gz', 'chartdate', 'base_anchor_year', dtypes=None, usecols=None)
proc[['subject_id', 'hadm_id', 'icd_code', 'chartdate', 'admittime', 'proc_time_from_admit']].dropna().to_csv("./data/features/preproc_proc.csv.gz", compression='gzip', index=False)
#proc.head()
# Out:
# # Unique ICD9 Procedures:   2560
# # Unique ICD10 Procedures:  10203
#
# Value counts of each ICD version:
#  9     463096
# 10    224075
# Name: icd_version, dtype: int64
#    subject_id   hadm_id  seq_num  chartdate icd_code  icd_version  \
# 0    10287061  27485182        1 2124-08-22     7569            9
# 1    13135573  22286210        3 2187-05-30     7309            9
# 2    13135573  22286210        1 2187-05-30     7569            9
# 3    13135573  22286210        2 2187-05-30      734            9
# 4    12646116  24154012        2 2115-01-13      734            9
#
#             admittime            dischtime proc_time_from_admit
# 0 2124-08-21 16:23:00  2124-08-24 13:00:00             07:37:00
# 1 2187-05-29 16:04:00  2187-05-31 12:40:00             07:56:00
# 2 2187-05-29 16:04:00  2187-05-31 12:40:00             07:56:00
# 3 2187-05-29 16:04:00  2187-05-31 12:40:00             07:56:00
# 4 2115-01-12 17:23:00  2115-01-17 13:40:00             06:37:00

# %%
med = preproc_meds("./mimic-iv-1.0/hosp/prescriptions.csv.gz", './data/cohort/cohort_non-icu_30_day_readmission.csv.gz','./utils/mappings/ndc_product.txt')
med[['subject_id', 'hadm_id', 'starttime','stoptime','drug','nonproprietaryname', 'start_hours_from_admit', 'stop_hours_from_admit']].to_csv('./data/features/preproc_med.csv.gz', compression='gzip', index=False)

# %%
diag = pd.read_csv("./data/features/preproc_diag.csv.gz", compression='gzip',header=0)
if(icd_orig):
    diag['new_icd_code']=diag['icd_code']
if(icd_convert):
    diag['new_icd_code']=diag['root_icd10_convert']
if(icd_group):
    diag['new_icd_code']=diag['root']

diag[['subject_id', 'hadm_id', 'new_icd_code']].dropna().to_csv("./data/features/preproc_diag.csv.gz", compression='gzip', index=False)

# %%
proc = pd.read_csv("./data/features/preproc_proc.csv.gz", compression='gzip',header=0)
if(proc_icd910):
    proc[['subject_id', 'hadm_id', 'icd_code', 'chartdate', 'admittime', 'proc_time_from_admit']].dropna().to_csv("./data/features/preproc_proc.csv.gz", compression='gzip', index=False)
elif(proc_icd10):
    proc.loc[proc.icd_version == 10][['subject_id', 'hadm_id', 'icd_code', 'chartdate', 'admittime', 'proc_time_from_admit']].dropna().to_csv("./data/features/preproc_proc.csv.gz", compression='gzip', index=False)

# %%
med = pd.read_csv("./data/features/preproc_med.csv.gz", compression='gzip',header=0)
if med_group:
    med['drug_name']=med['nonproprietaryname']
if med_group:
    med['drug_name']=med['drug']
med[['subject_id', 'hadm_id', 'starttime','stoptime','drug_name', 'start_hours_from_admit', 'stop_hours_from_admit']].dropna().to_csv('./data/features/preproc_med.csv.gz', compression='gzip', index=False)

# %%
dat = pd.read_csv("./mimic-iv-1.0/icu/chartevents.csv.gz", compression='gzip', header=0)
dat.head()

# %%
dat = pd.read_csv("./mimic-iv-1.0/icu/d_items.csv.gz", compression='gzip', header=0)
dat.head()
# Out:
#    itemid                    label        abbreviation         linksto  \
# 0  220003       ICU Admission date  ICU Admission date  datetimeevents
# 1  220045               Heart Rate                  HR     chartevents
# 2  220046  Heart rate Alarm - High     HR Alarm - High     chartevents
# 3  220047   Heart Rate Alarm - Low      HR Alarm - Low     chartevents
# 4  220048             Heart Rhythm        Heart Rhythm     chartevents
#
#               category unitname     param_type  lownormalvalue  \
# 0                  ADT      NaN  Date and time             NaN
# 1  Routine Vital Signs      bpm        Numeric             NaN
# 2               Alarms      bpm        Numeric             NaN
# 3               Alarms      bpm        Numeric             NaN
# 4  Routine Vital Signs      NaN           Text             NaN
#
#    highnormalvalue
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
dat = pd.read_csv("./mimic-iv-1.0/icu/datetimeevents.csv.gz", compression='gzip', header=0)
dat.head()
# Out:
#    subject_id   hadm_id   stay_id            charttime            storetime  \
# 0    10003700  28623837  30600691  2165-04-24 05:42:00  2165-04-24 05:42:00
# 1    10003700  28623837  30600691  2165-04-24 08:00:00  2165-04-24 08:26:00
# 2    10004235  24181354  34100191  2196-02-24 18:06:00  2196-02-24 18:07:00
# 3    10004235  24181354  34100191  2196-02-24 18:06:00  2196-02-24 18:07:00
# 4    10004235  24181354  34100191  2196-02-24 18:06:00  2196-02-24 18:07:00
#
#    itemid                value       valueuom  warning
# 0  225755  2165-04-24 05:42:00           Date        0
# 1  225755  2165-04-24 00:00:00           Date        0
# 2  224261  2196-02-24 18:06:00           Date        0
# 3  224279  2196-02-24 18:06:00  Date and Time        0
# 4  224280  2196-02-24 18:06:00           Date        0

# %%
dat = pd.read_csv("./mimic-iv-1.0/icu/inputevents.csv.gz", compression='gzip', header=0)
dat.head()
# Out:
#    subject_id   hadm_id   stay_id            starttime              endtime  \
# 0    12481680  26876606  30863119  2141-01-23 17:37:00  2141-01-23 17:38:00
# 1    12481680  26876606  30863119  2141-01-23 13:00:00  2141-01-23 13:01:00
# 2    12481680  26876606  30863119  2141-01-23 11:00:00  2141-01-23 11:01:00
# 3    12481680  26876606  30863119  2141-01-23 14:16:00  2141-01-23 14:17:00
# 4    15614172  27424463  33484414  2153-07-30 23:16:00  2153-07-30 23:17:00
#
#              storetime  itemid  amount amountuom  rate  ...  \
# 0  2141-01-23 17:37:00  226452   180.0        ml   NaN  ...
# 1  2141-01-23 13:23:00  226452   240.0        ml   NaN  ...
# 2  2141-01-23 12:24:00  226452   120.0        ml   NaN  ...
# 3  2141-01-23 14:17:00  226452    60.0        ml   NaN  ...
# 4  2153-07-30 23:16:00  226452   100.0        ml   NaN  ...
#
#   ordercategorydescription  patientweight  totalamount totalamountuom  \
# 0                    Bolus          123.0        180.0             ml
# 1                    Bolus          123.0        240.0             ml
# 2                    Bolus          123.0        120.0             ml
# 3                    Bolus          123.0         60.0             ml
# 4                    Bolus           71.6        100.0             ml
#
#   isopenbag continueinnextdept cancelreason  statusdescription  \
# 0         0                  0            0    FinishedRunning
# 1         0                  0            0    FinishedRunning
# 2         0                  0            0    FinishedRunning
# 3         0                  0            0    FinishedRunning
# 4         0                  0            0    FinishedRunning
#
#    originalamount originalrate
# 0           180.0        180.0
# 1           240.0        240.0
# 2           120.0        120.0
# 3            60.0         60.0
# 4           100.0        100.0
#
# [5 rows x 26 columns]

# %%
dat = pd.read_csv("./mimic-iv-1.0/icu/outputevents.csv.gz", compression='gzip', header=0)
dat.head()
# Out:
#    subject_id   hadm_id   stay_id            charttime            storetime  \
# 0    10003700  28623837  30600691  2165-04-24 05:40:00  2165-04-24 05:44:00
# 1    10004235  24181354  34100191  2196-02-24 17:55:00  2196-02-24 17:55:00
# 2    10004235  24181354  34100191  2196-02-24 19:00:00  2196-02-24 19:43:00
# 3    10004235  24181354  34100191  2196-02-24 20:00:00  2196-02-24 20:02:00
# 4    10004235  24181354  34100191  2196-02-24 21:00:00  2196-02-24 20:56:00
#
#    itemid  value valueuom
# 0  226559  300.0       ml
# 1  226559  100.0       ml
# 2  226559   45.0       ml
# 3  226559   45.0       ml
# 4  226559   45.0       ml

# %%
dat = pd.read_csv("./mimic-iv-1.0/icu/procedureevents.csv.gz", compression='gzip', header=0)
dat.head()
# Out:
#    subject_id   hadm_id   stay_id            starttime              endtime  \
# 0    15693895  21203492  30500789  2147-06-05 11:25:00  2147-06-05 11:26:00
# 1    15693895  21203492  30500789  2147-06-05 22:00:00  2147-06-05 22:01:00
# 2    12481680  26876606  30863119  2141-01-23 12:00:00  2141-01-23 18:33:00
# 3    12481680  26876606  30863119  2141-01-23 12:00:00  2141-01-23 18:33:00
# 4    15614172  27424463  33484414  2153-07-29 18:13:00  2153-07-31 01:25:00
#
#                 storetime  itemid   value valueuom         location  ...  \
# 0     2147-06-06 11:25:00  225399     1.0     None              NaN  ...
# 1     2147-06-06 11:25:00  224385     1.0     None              NaN  ...
# 2  2141-01-23 18:33:51.14  224275   393.0      min              NaN  ...
# 3  2141-01-23 18:33:51.14  224275   393.0      min              NaN  ...
# 4     2153-07-31 01:26:00  224277  1872.0      min  RL Post Forearm  ...
#
#   patientweight  totalamount  totalamountuom isopenbag  continueinnextdept  \
# 0          80.0          NaN             NaN         0                   0
# 1          80.0          NaN             NaN         0                   0
# 2         123.0          NaN             NaN         1                   0
# 3         123.0          NaN             NaN         1                   0
# 4          71.6          NaN             NaN         1                   1
#
#   cancelreason  statusdescription  comments_date  originalamount  originalrate
# 0            0    FinishedRunning            NaN             1.0             0
# 1            0    FinishedRunning            NaN             1.0             0
# 2            0    FinishedRunning            NaN           393.0             1
# 3            0    FinishedRunning            NaN           393.0             1
# 4            0    FinishedRunning            NaN          1872.0             1
#
# [5 rows x 26 columns]
