# %%
import pandas as pd
cohort = pd.read_csv('d_labitems.csv.gz', compression='gzip')
import numpy as np

# %%
cohort.head()
# Out:
#    itemid                      label             fluid    category loinc_code
# 0   51905                             Other Body Fluid   Chemistry          0
# 1   51532     11-Deoxycorticosterone             Blood   Chemistry          0
# 2   51957  17-Hydroxycorticosteroids             Urine   Chemistry          0
# 3   51958     17-Ketosteroids, Urine             Urine   Chemistry          0
# 4   52068                      24 Hr             Blood  Hematology          0

# %%
cohort=cohort.fillna(0)
cohort.dropna(inplace=True)

# %%
clist=['alanine aminotransferase', 'albumin', 'albumin ascites', 'albumin pleural', 'albumin urine', 'alkaline phosphate', 'anion gap', 'asparate aminotransferase', 'basophils', 'bicarbonate', 'bilirubin', 'blood urea nitrogen', 'calcium', 'calcium ionized', 'calcium urine', 'cardiac index', 'cardiac output fick', 'cardiac output thermodilution', 'central venous pressure', 'chloride', 'chloride urine', 'cholesterol', 'cholesterol hdl', 'cholesterol ldl', 'co2', 'co2 (etco2, pco2, etc.)', 'creatinine', 'creatinine ascites', 'creatinine body fluid', 'creatinine pleural', 'creatinine urine', 'diastolic blood pressure', 'eosinophils', 'fibrinogen', 'fraction inspired oxygen', 'fraction inspired oxygen set', 'glascow coma scale total', 'glucose', 'heart rate', 'height', 'hematocrit', 'hemoglobin', 'lactate', 'lactate dehydrogenase', 'lactate dehydrogenase pleural', 'lactic acid', 'lymphocytes', 'lymphocytes ascites', 'lymphocytes atypical', 'lymphocytes atypical csl', 'lymphocytes body fluid', 'lymphocytes percent', 'lymphocytes pleural', 'magnesium', 'mean blood pressure', 'mean corpuscular hemoglobin', 'mean corpuscular hemoglobin concentration', 'mean corpuscular volume', 'monocytes', 'monocytes csl', 'neutrophils', 'oxygen saturation', 'partial pressure of carbon dioxide', 'partial pressure of oxygen', 'partial thromboplastin time', 'peak inspiratory pressure', 'ph', 'ph urine', 'phosphate', 'phosphorous', 'plateau pressure', 'platelets', 'positive end-expiratory pressure', 'positive end-expiratory pressure set', 'post void residual', 'potassium', 'potassium serum', 'prothrombin time inr', 'prothrombin time pt', 'pulmonary artery pressure mean', 'pulmonary artery pressure systolic', 'pulmonary capillary wedge pressure', 'red blood cell count', 'red blood cell count ascites', 'red blood cell count csf', 'red blood cell count pleural', 'red blood cell count urine', 'respiratory rate', 'respiratory rate set', 'sodium', 'systemic vascular resistance', 'systolic blood pressure', 'temperature', 'tidal volume observed', 'tidal volume set', 'tidal volume spontaneous', 'total protein', 'total protein urine', 'troponin-i', 'troponin-t', 'venous pvo2', 'weight', 'white blood cell count', 'white blood cell count urine']

# %%
cohort[cohort['label'].str.contains('albumin',case=False,na=False)]
# Out:
#       itemid                      label                fluid   category  \
# 54     51520                  (Albumin)              Ascites  Chemistry
# 55     51542                  (Albumin)                Blood  Chemistry
# 56     51775                  (Albumin)  Cerebrospinal Fluid  Chemistry
# 57     51807                  (Albumin)          Joint Fluid  Chemistry
# 58     51910                  (Albumin)              Pleural  Chemistry
# 59     51926                  (Albumin)                Stool  Chemistry
# 60     51776                  <Albumin>  Cerebrospinal Fluid  Chemistry
# 61     51836                  <Albumin>     Other Body Fluid  Chemistry
# 62     50862                    Albumin                Blood  Chemistry
# 63     50835           Albumin, Ascites              Ascites  Chemistry
# 64     52022             Albumin, Blood                Blood  Blood Gas
# 65     51025        Albumin, Body Fluid     Other Body Fluid  Chemistry
# 66     51070  Albumin/Creatinine, Urine                Urine  Chemistry
# 67     51777               Albumin, CSF  Cerebrospinal Fluid  Chemistry
# 68     51019       Albumin, Joint Fluid          Joint Fluid  Chemistry
# 69     51046           Albumin, Pleural              Pleural  Chemistry
# 70     51927             Albumin, Stool                Stool  Chemistry
# 71     51069             Albumin, Urine                Urine  Chemistry
# 72     52703             Albumin, Urine                Urine  Chemistry
# 1419   51897         Surfactant/Albumin     Other Body Fluid  Chemistry
#
#      loinc_code
# 54            0
# 55       2862-1
# 56            0
# 57            0
# 58            0
# 59            0
# 60            0
# 61            0
# 62       1751-7
# 63            0
# 64            0
# 65            0
# 66      14958-3
# 67            0
# 68            0
# 69            0
# 70            0
# 71            0
# 72            0
# 1419          0

# %%
for i in clist:
    #i=i.split()[0]
    print(i)
    print(list(cohort[cohort['label'].str.contains(i,case=False,na=False)]['label']))
# Out:
# alanine aminotransferase
# ['Alanine Aminotransferase (ALT)']
# albumin
# ['(Albumin)', '(Albumin)', '(Albumin)', '(Albumin)', '(Albumin)', '(Albumin)', '<Albumin>', '<Albumin>', 'Albumin', 'Albumin, Ascites', 'Albumin, Blood', 'Albumin, Body Fluid', 'Albumin/Creatinine, Urine', 'Albumin, CSF', 'Albumin, Joint Fluid', 'Albumin, Pleural', 'Albumin, Stool', 'Albumin, Urine', 'Albumin, Urine', 'Surfactant/Albumin']
# albumin ascites
# []
# albumin pleural
# []
# albumin urine
# []
# alkaline phosphate
# []
# anion gap
# ['Anion Gap', 'Anion Gap']
# asparate aminotransferase
# ['Asparate Aminotransferase (AST)']
# basophils
# ['Basophils', 'Basophils', 'Basophils', 'Basophils', 'Basophils', 'Basophils']
# bicarbonate
# ['Bicarbonate', 'Bicarbonate, Ascites', 'Bicarbonate, CSF', 'Bicarbonate,Joint Fluid', 'Bicarbonate, Other Fluid', 'Bicarbonate, Pleural', 'Bicarbonate, Stool', 'Bicarbonate, Urine', 'Calculated Bicarbonate', 'Calculated Bicarbonate, Whole Blood']
# bilirubin
# ['Bilirubin', 'Bilirubin', 'Bilirubin Crystals', 'Bilirubin, Direct', 'Bilirubin, Indirect', 'Bilirubin, Neonatal', 'Bilirubin, Neonatal, Direct', 'Bilirubin, Neonatal, Indirect', 'Bilirubin, Total', 'Bilirubin, Total, Ascites', 'Bilirubin, Total, Body Fluid', 'Bilirubin, Total, CSF', 'Bilirubin, Total, Joint Fluid', 'Bilirubin, Total, Pleural', 'Bilirubin, Total, Stool']
# blood urea nitrogen
# []
# calcium
# ['24 hr Calcium', 'Calcium, Body Fluid', 'Calcium Carbonate Crystals', 'Calcium Oxalate Crystals', 'Calcium Phosphate Crystals', 'Calcium, Total', 'Calcium, Urine', 'Free Calcium', 'Free Calcium', '% Ionized Calcium', 'Total Calcium', 'Total Calcium']
# calcium ionized
# []
# calcium urine
# []
# cardiac index
# []
# cardiac output fick
# []
# cardiac output thermodilution
# []
# central venous pressure
# []
# chloride
# ['Chloride', 'Chloride', 'Chloride, Ascites', 'Chloride, Body Fluid', 'Chloride, CSF', 'Chloride, Joint Fluid', 'Chloride, Pleural', 'Chloride, Stool', 'Chloride, Urine', 'Chloride, Whole Blood', 'Chloride, Whole Blood']
# chloride urine
# []
# cholesterol
# ['Cholesterol, Ascites', 'Cholesterol, Body Fluid', 'Cholesterol Crystals', 'Cholesterol, CSF', 'Cholesterol, HDL', 'Cholesterol, Joint Fluid', 'Cholesterol, LDL, Calculated', 'Cholesterol, LDL, Measured', 'Cholesterol, Pleural', 'Cholesterol Ratio (Total/HDL)', 'Cholesterol, Stool', 'Cholesterol, Total']
# cholesterol hdl
# []
# cholesterol ldl
# []
# co2
# ['Calculated Total CO2', 'pCO2', 'pCO2', 'pCO2, Body Fluid', 'Total CO2', 'WB tCO2']
# co2 (etco2, pco2, etc.)
# []
# creatinine
# ['24 hr Creatinine', 'Albumin/Creatinine, Urine', 'Amylase/Creatinine Clearance', 'Amylase/Creatinine Ratio, Urine', 'Creatinine', 'Creatinine', 'Creatinine, Ascites', 'Creatinine, Blood', 'Creatinine, Body Fluid', 'Creatinine Clearance', 'Creatinine, CSF', 'Creatinine, Joint Fluid', 'Creatinine, Pleural', 'Creatinine, Serum', 'Creatinine, Stool', 'Creatinine, Urine', 'Creatinine, Whole Blood', 'Protein/Creatinine Ratio', 'Urine  Creatinine', 'Urine Creatinine']
# creatinine ascites
# []
# creatinine body fluid
# []
# creatinine pleural
# []
# creatinine urine
# []
# diastolic blood pressure
# []
# eosinophils
# ['Eosinophils', 'Eosinophils', 'Eosinophils', 'Eosinophils', 'Eosinophils', 'Eosinophils', 'Eosinophils']
# fibrinogen
# ['Fibrinogen', 'Fibrinogen', 'Fibrinogen, Functional', 'Fibrinogen, Immunologic']
# fraction inspired oxygen
# []
# fraction inspired oxygen set
# []
# glascow coma scale total
# []
# glucose
# ['Glucose', 'Glucose', 'Glucose', 'Glucose', 'Glucose', 'Glucose, Ascites', 'Glucose, Body Fluid', 'Glucose, CSF', 'Glucose, Joint Fluid', 'Glucose, Pleural', 'Glucose, Stool', 'Glucose, Urine', 'Glucose, Whole Blood']
# heart rate
# []
# height
# []
# hematocrit
# ['Hematocrit', 'Hematocrit', 'Hematocrit', 'Hematocrit', 'Hematocrit', 'Hematocrit, Ascites', 'Hematocrit, Calculated', 'Hematocrit, CSF', 'Hematocrit, Joint Fluid', 'Hematocrit, Other Fluid', 'Hematocrit, Pleural']
# hemoglobin
# ['Absolute Hemoglobin', 'Carboxyhemoglobin', 'Fetal Hemoglobin', 'Glycated Hemoglobin', 'Hemoglobin', 'Hemoglobin', 'Hemoglobin', 'Hemoglobin  A', 'Hemoglobin  A1', '% Hemoglobin A1c', 'Hemoglobin  A2', 'Hemoglobin A2', 'Hemoglobin  C', 'Hemoglobin C', 'Hemoglobin, Calculated', 'Hemoglobin  F', 'Hemoglobin F', 'Hemoglobin H Inclusion', 'Hemoglobin Other', 'Hemoglobin  S', 'Methemoglobin', 'Methemoglobin', 'P50 of Hemoglobin', 'Plasma Hemoglobin', 'Reticulocyte, Cellular Hemoglobin']
# lactate
# ['Lactate', 'Lactate', 'Lactate Dehydrogenase, Ascites', 'Lactate Dehydrogenase, CSF', 'Lactate Dehydrogenase (LD)', 'Lactate Dehydrogenase, Pleural', 'Lactate Dehydrogenase, Stool']
# lactate dehydrogenase
# ['Lactate Dehydrogenase, Ascites', 'Lactate Dehydrogenase, CSF', 'Lactate Dehydrogenase (LD)', 'Lactate Dehydrogenase, Pleural', 'Lactate Dehydrogenase, Stool']
# lactate dehydrogenase pleural
# []
# lactic acid
# []
# lymphocytes
# ['Atypical Lymphocytes', 'Atypical Lymphocytes', 'Atypical Lymphocytes', 'Atypical Lymphocytes', 'Atypical Lymphocytes', 'Atypical Lymphocytes', 'Lymphocytes', 'Lymphocytes', 'Lymphocytes', 'Lymphocytes', 'Lymphocytes', 'Lymphocytes', 'Lymphocytes, Percent']
# lymphocytes ascites
# []
# lymphocytes atypical
# []
# lymphocytes atypical csl
# []
# lymphocytes body fluid
# []
# lymphocytes percent
# []
# lymphocytes pleural
# []
# magnesium
# ['Magnesium', 'Magnesium, Body Fluid', 'Magnesium, Urine']
# mean blood pressure
# []
# mean corpuscular hemoglobin
# []
# mean corpuscular hemoglobin concentration
# []
# mean corpuscular volume
# []
# monocytes
# ['Monocytes', 'Monocytes', 'Monocytes', 'Monocytes']
# monocytes csl
# []
# neutrophils
# ['Hypersegmented  Neutrophils#', 'Hypersegmented Neutrophils', 'Hypersegmented Neutrophils', 'Hypersegmented Neutrophils', 'Hypersegmented Neutrophils', 'Hypersegmented Neutrophils', 'Hypersegmented Neutrophils #', 'Hypersegmented Neutrophils #', 'Hypersegmented Neutrophils#', 'Neutrophils', 'Neutrophils']
# oxygen saturation
# ['Oxygen Saturation']
# partial pressure of carbon dioxide
# []
# partial pressure of oxygen
# []
# partial thromboplastin time
# []
# peak inspiratory pressure
# []
# ph
# ['Absolute Basophil Count', 'Absolute Eosinophil Count', 'Absolute Lymphocyte Count', 'Absolute Lymphocyte Count', 'Absolute Lymphocyte Count', 'Absolute Neutrophil', 'Absolute Neutrophil Count', 'Acetaminophen', 'Acid Phosphatase', 'Acid Phosphatase, Non-Prostatic', 'Acid Phosphatase, Prostatic Fraction', 'Acid Phosphatase Stain', 'Acid Phosphatase Stain', 'Adrenocorticotrophic Hormone', 'Alkaline Phosphatase', 'Alpha-1', 'Alpha-1', 'Alpha-1', 'Alpha-1', 'Alpha-1', 'Alpha-1', 'Alpha-1', 'Alpha-1', 'Alpha-1-antitrypsin', 'Alpha-2', 'Alpha-2', 'Alpha-2', 'Alpha-2', 'Alpha-2', 'Alpha-2', 'Alpha-2', 'Alpha-2', 'Alpha Antiplasmin', 'Alpha-Fetoprotein', 'Amorphous Crystals', 'Amphetamine Screen, Urine', 'Anti-Neutrophil Cytoplasmic Antibody', 'Atypical Lymphocytes', 'Atypical Lymphocytes', 'Atypical Lymphocytes', 'Atypical Lymphocytes', 'Atypical Lymphocytes', 'Atypical Lymphocytes', 'Basophilic Stippling', 'Basophils', 'Basophils', 'Basophils', 'Basophils', 'Basophils', 'Basophils', 'Calcium Phosphate Crystals', 'Coproporphyrins', 'Eosinophil Count', 'Eosinophils', 'Eosinophils', 'Eosinophils', 'Eosinophils', 'Eosinophils', 'Eosinophils', 'Eosinophils', 'Epinepherine', 'Heinz Aph', 'Hypersegmented  Neutrophils#', 'Hypersegmented Neutrophils', 'Hypersegmented Neutrophils', 'Hypersegmented Neutrophils', 'Hypersegmented Neutrophils', 'Hypersegmented Neutrophils', 'Hypersegmented Neutrophils #', 'Hypersegmented Neutrophils #', 'Hypersegmented Neutrophils#', 'Hyphenated Yeast', 'Immunoelectrophoresis', 'Immunoelectrophoresis, Ascites', 'Immunoelectrophoresis, CSF', 'Immunoelectrophoresis, Fluid', 'Immunoelectrophoresis, Joint Fluid', 'Immunoelectrophoresis, Pleural', 'Immunoelectrophoresis, Stool', 'Immunoelectrophoresis, Urine', 'Immunophenotyping', 'Immunophenotyping', 'Immunophenotyping', 'Immunophenotyping', 'Leukocyte Alkaline Phosphatase', 'Lipo Electrophoresis', 'Lymphocytes', 'Lymphocytes', 'Lymphocytes', 'Lymphocytes', 'Lymphocytes', 'Lymphocytes', 'Lymphocytes, Percent', 'Lymphs', 'Lymphs#', 'Lymphs#', 'Lymphs#', 'Lymphs#', 'Lymphs#', 'Macrophage', 'Macrophage', 'Macrophage', 'Macrophage', 'Macrophage#', 'Macrophages', 'Naphthol Acetate Stain', 'Naphthol Butryrate', 'Naphtol Acetate Stain', 'Neutrophils', 'Neutrophils', 'pH', 'pH', 'pH', 'pH', 'pH', 'pH', 'Phenobarbital', 'Phenothiazine Screen, Urine', 'Phenytoin', 'Phenytoin, Free', 'Phenytoin, Percent Free', 'Phosphate', 'Phosphate, Body Fluid', 'Phosphate, Urine', 'Phosphatidylglycerol', 'pH, Urine', 'Porphobilinogen Screen', 'Propoxyphene, Urine', 'Protein Electrophoresis', 'Prot. Electrophoresis, Urine', 'RBC Morphology', 'Spherocytes', 'Staph aureus PCR', 'TCR Alpha-Beta', 'TCR Alpha-Beta', 'TCR Alpha-Beta', 'Theophylline', 'Treponema pallidum (Syphilis) Ab', 'Treponema pallidum (syphilis) value', 'Triple Phosphate Crystals', 'Uroporphyrins']
# ph urine
# []
# phosphate
# ['Calcium Phosphate Crystals', 'Phosphate', 'Phosphate, Body Fluid', 'Phosphate, Urine', 'Triple Phosphate Crystals']
# phosphorous
# []
# plateau pressure
# []
# platelets
# ['Large Platelets']
# positive end-expiratory pressure
# []
# positive end-expiratory pressure set
# []
# post void residual
# []
# potassium
# ['Potassium', 'Potassium', 'Potassium', 'Potassium, Ascites', 'Potassium, Body Fluid', 'Potassium, CSF', 'Potassium, Joint Fluid', 'Potassium, Pleural', 'Potassium, Stool', 'Potassium, Urine', 'Potassium, Urine', 'Potassium, Whole Blood', 'Potassium, Whole Blood']
# potassium serum
# []
# prothrombin time inr
# []
# prothrombin time pt
# []
# pulmonary artery pressure mean
# []
# pulmonary artery pressure systolic
# []
# pulmonary capillary wedge pressure
# []
# red blood cell count
# []
# red blood cell count ascites
# []
# red blood cell count csf
# []
# red blood cell count pleural
# []
# red blood cell count urine
# []
# respiratory rate
# []
# respiratory rate set
# []
# sodium
# ['Sodium', 'Sodium', 'Sodium, Ascites', 'Sodium, Body Fluid', 'Sodium, Body Fluid', 'Sodium, CSF', 'Sodium, Joint Fluid', 'Sodium, Pleural', 'Sodium, Stool', 'Sodium, Urine', 'Sodium, Urine', 'Sodium, Whole Blood', 'Sodium, Whole Blood']
# systemic vascular resistance
# []
# systolic blood pressure
# []
# temperature
# ['Temperature']
# tidal volume observed
# []
# tidal volume set
# []
# tidal volume spontaneous
# []
# total protein
# ['Total Protein, Ascites', 'Total Protein, Body Fluid', 'Total Protein, CSF', 'Total Protein, Joint Fluid', 'Total Protein, Pleural', 'Total Protein, Stool', 'Total Protein, Urine']
# total protein urine
# []
# troponin-i
# []
# troponin-t
# []
# venous pvo2
# []
# weight
# []
# white blood cell count
# []
# white blood cell count urine
# []
# C:\Users\mehak\Anaconda3\envs\DSRA\lib\site-packages\pandas\core\strings.py:1952: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
clist=[]

# %%
clist=['Albumin','Alkaline Phosphate','Anion gap','Bicarbonate Base','Total Bilirubin','Ionized Calcium',
'Calcium Gluconate','Cardiac Index (CI NICOM)', 'Central Venous Pressure', 'Chloride (whole blood)','Cholesterol',
'Creatinine (serum)','Creatinine (whole blood)', 'CO2 production','LDL measured','HDL', 'Fibrinogen','Heart Rate', 
'Glucose (whole blood)', 'Height (cm)','Hematocrit (whole blood - calc)',
'Hemoglobin','Lactic Acid','Magnesium','Arterial Blood Pressure mean','Arterial Blood Pressure systolic',
'Arterial Blood Pressure diastolic','PAR-Oxygen saturation','Phosphorous','Platelets','Plateau Pressure''PH (Venous)',
'Pulmonary Artery Pressure mean','Pulmonary Artery Pressure systolic''Respiratory Rate', 'Sodium (whole blood)',
'Temperature Fahrenheit','Total Protein','Troponin-T','Daily Weight']

# %%
len(clist)
# Out:
# 38

# %%
cohort=cohort[cohort['label'].isin(clist)]

# %%
list(cohort['itemid'])
# Out:
# [220045,
#  220050,
#  220051,
#  220052,
#  220061,
#  220074,
#  220228,
#  220245,
#  220603,
#  220615,
#  220624,
#  220635,
#  220650,
#  221456,
#  223761,
#  224639,
#  225165,
#  225170,
#  225612,
#  225667,
#  225668,
#  225677,
#  225690,
#  226534,
#  226536,
#  226537,
#  226540,
#  226730,
#  227073,
#  227429,
#  227441,
#  227456,
#  227468,
#  228232,
#  228368,
#  229761]

# %%
cohort[cohort['label'].str.contains('urine',case=False)]
# Out:
#       itemid                         label                  abbreviation  \
# 65    220799     ZSpecific Gravity (urine)     ZSpecific gravity (urine)
# 360   224015                  Urine Source                  Urine Source
# 361   224016                   Urine Color                   Urine Color
# 713   224876              Urine Appearance              Urine Appearance
# 1025  225454                 Urine Culture                 Urine Culture
# 1469  226566     Urine and GU Irrigant Out     Urine and GU Irrigant Out
# 1520  226627                      OR Urine                      OR Urine
# 1524  226631                    PACU Urine                    PACU Urine
# 1682  227059           UrineScore_ApacheIV           UrineScore_ApacheIV
# 1782  227471      Specific Gravity (urine)      Specific Gravity (urine)
# 1787  227489  GU Irrigant/Urine Volume Out  GU Irrigant/Urine Volume Out
# 1792  227519         Urine output_ApacheIV                  Urine output
#
#               linksto                category unitname        param_type  \
# 65        chartevents                    Labs     None           Numeric
# 360       chartevents                   GI/GU      NaN              Text
# 361       chartevents                   GI/GU      NaN              Text
# 713       chartevents                   GI/GU      NaN              Text
# 1025  procedureevents              6-Cultures     None         Processes
# 1469     outputevents                  Output       mL           Numeric
# 1520     outputevents                  Output       mL           Numeric
# 1524     outputevents                  Output       mL           Numeric
# 1682      chartevents  Scores - APACHE IV (2)     None           Numeric
# 1782      chartevents                    Labs     None  Numeric with tag
# 1787     outputevents                  Output       mL           Numeric
# 1792      chartevents  Scores - APACHE IV (2)     None           Numeric
#
#       lownormalvalue  highnormalvalue
# 65               NaN              NaN
# 360              NaN              NaN
# 361              NaN              NaN
# 713              NaN              NaN
# 1025             NaN              NaN
# 1469             NaN              NaN
# 1520             NaN              NaN
# 1524             NaN              NaN
# 1682             NaN              NaN
# 1782             NaN              NaN
# 1787             NaN              NaN
# 1792             NaN              NaN

# %%
df = pd.Series(np.random.rand(3), index=["a","b","c"]).to_frame().T
print(df)
df.columns = pd.MultiIndex.from_product([["new_label"], df.columns])
# Out:
#           a         b         c
# 0  0.085835  0.750664  0.112239
