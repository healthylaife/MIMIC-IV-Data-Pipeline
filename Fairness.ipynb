# %%
import os
import pickle
import pandas as pd
import numpy as np

# %% [markdown]
# ##### Path to outputdict file

# %%
output_dict_path = "outputDictNew" #path to output dict

# %%
os.path.isfile(output_dict_path)
# Out:
# True

# %% [markdown]
# ##### Load the file

# %%
output_dict = pickle.load(open(output_dict_path,"rb"))

# %%
output_dict
# Out:
#       Labels      Prob    Logits               ethnicity gender  age
# 0        0.0  0.005472 -5.202624  BLACK/AFRICAN AMERICAN      F   57
# 1        0.0  0.001005 -6.902061  BLACK/AFRICAN AMERICAN      M   68
# 2        0.0  0.019099 -3.938828                   WHITE      F   87
# 3        0.0  0.008335 -4.778972                   WHITE      M   46
# 4        0.0  0.004045 -5.506170                   WHITE      M   68
# ...      ...       ...       ...                     ...    ...  ...
# 7895     0.0  0.003010 -5.802665  BLACK/AFRICAN AMERICAN      F   31
# 7896     0.0  0.033274 -3.369145                   WHITE      M   83
# 7897     0.0  0.013597 -4.284217         HISPANIC/LATINO      M   35
# 7898     1.0  0.305867 -0.819511                   WHITE      M   75
# 7899     0.0  0.027468 -3.566888                   WHITE      M   78
#
# [7900 rows x 6 columns]

# %% [markdown]
# ##### Add predicted label using the probability

# %%
output_dict["Predicted"] = output_dict.apply(lambda row:1 if row.Prob>=0.5 else 0, axis=1)

# %%
output_dict
# Out:
#       Labels      Prob    Logits               ethnicity gender  age  \
# 0        0.0  0.005472 -5.202624  BLACK/AFRICAN AMERICAN      F   57
# 1        0.0  0.001005 -6.902061  BLACK/AFRICAN AMERICAN      M   68
# 2        0.0  0.019099 -3.938828                   WHITE      F   87
# 3        0.0  0.008335 -4.778972                   WHITE      M   46
# 4        0.0  0.004045 -5.506170                   WHITE      M   68
# ...      ...       ...       ...                     ...    ...  ...
# 7895     0.0  0.003010 -5.802665  BLACK/AFRICAN AMERICAN      F   31
# 7896     0.0  0.033274 -3.369145                   WHITE      M   83
# 7897     0.0  0.013597 -4.284217         HISPANIC/LATINO      M   35
# 7898     1.0  0.305867 -0.819511                   WHITE      M   75
# 7899     0.0  0.027468 -3.566888                   WHITE      M   78
#
#       Predicted
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 7895          0
# 7896          0
# 7897          0
# 7898          0
# 7899          0
#
# [7900 rows x 7 columns]

# %% [markdown]
# ##### Bin age

# %%
output_dict["age_binned"] = output_dict.age.apply(lambda x:"{}-{}".format((x//10)*10,(x//10 + 1)*10))

# %% [markdown]
# ##### List of sensitive columns

# %%
sensitive_columns = ["ethnicity", "gender", "age_binned"]

# %% [markdown]
# ##### Function to compute the Confusion Matrix parameters

# %%
def get_cm_parameters(gt, pred):
    zipped_gt_pred = list(zip(gt,pred))
    tp = len([pair for pair in zipped_gt_pred if pair == (1,1)])
    tn = len([pair for pair in zipped_gt_pred if pair == (0,0)])
    fp = len([pair for pair in zipped_gt_pred if pair == (0,1)])
    fn = len([pair for pair in zipped_gt_pred if pair == (1,0)])
    
    try:
        tpr = tp/(tp + fn)
    except ZeroDivisionError:
        tpr = None
    try:
        tnr = tn/(tn + fp)
    except ZeroDivisionError:
        tnr = None
    try:
        fpr = fp/(fp + tn)
    except ZeroDivisionError:
        fpr = None
    try:
        fnr = fn/(fn + tp)
    except ZeroDivisionError:
        fnr = None
    try:
        pr = (tp + fp)/(len(zipped_gt_pred))
    except:
        pr = None
    try:
        nr = (tn + fn)/(len(zipped_gt_pred))
    except:
        nr = None
    try:
        acc = (tp+tn)/(len(zipped_gt_pred))
    except ZeroDivisionError:
        acc = None
    
    return tp, tn, fp, fn, tpr, tnr, fpr, fnr, pr, nr, acc

# %% [markdown]
# ##### Generate fairness report

# %%
report_list = []
for sens_col in sensitive_columns:
    for group, aggregate in output_dict.groupby(sens_col):
        tmp_dct = {"sensitive_attribute": sens_col}
        tp, tn, fp, fn, tpr, tnr, fpr, fnr, pr, nr, acc = get_cm_parameters(list(aggregate.Labels), list(aggregate.Predicted))
        tmp_dct.update(dict(
            group=group,tp=tp, tn=tn, fp=fp, fn=fn, tpr=tpr, tnr=tnr, fpr= fpr, fnr=fnr, pr=pr, nr=nr, accuracy=acc    
            )
        )
        report_list.append(tmp_dct)

# %%
report = pd.DataFrame(report_list)
report_groups = {c:i for i,c in enumerate(report.sensitive_attribute.unique())}

# %%
def highlight(s):
    colors = [['background-color: yellow'], ['background-color: green'], ['background-color: red']]
    return colors[report_groups[s.sensitive_attribute]%len(colors)] * len(s)

# %%
try:
    import jinja2
    display(report.style.apply(highlight, axis=1))
except ImportError:
    display(report)
# Out:
# <style type="text/css">
# #T_d52bd_row0_col0, #T_d52bd_row0_col1, #T_d52bd_row0_col2, #T_d52bd_row0_col3, #T_d52bd_row0_col4, #T_d52bd_row0_col5, #T_d52bd_row0_col6, #T_d52bd_row0_col7, #T_d52bd_row0_col8, #T_d52bd_row0_col9, #T_d52bd_row0_col10, #T_d52bd_row0_col11, #T_d52bd_row0_col12, #T_d52bd_row1_col0, #T_d52bd_row1_col1, #T_d52bd_row1_col2, #T_d52bd_row1_col3, #T_d52bd_row1_col4, #T_d52bd_row1_col5, #T_d52bd_row1_col6, #T_d52bd_row1_col7, #T_d52bd_row1_col8, #T_d52bd_row1_col9, #T_d52bd_row1_col10, #T_d52bd_row1_col11, #T_d52bd_row1_col12, #T_d52bd_row2_col0, #T_d52bd_row2_col1, #T_d52bd_row2_col2, #T_d52bd_row2_col3, #T_d52bd_row2_col4, #T_d52bd_row2_col5, #T_d52bd_row2_col6, #T_d52bd_row2_col7, #T_d52bd_row2_col8, #T_d52bd_row2_col9, #T_d52bd_row2_col10, #T_d52bd_row2_col11, #T_d52bd_row2_col12, #T_d52bd_row3_col0, #T_d52bd_row3_col1, #T_d52bd_row3_col2, #T_d52bd_row3_col3, #T_d52bd_row3_col4, #T_d52bd_row3_col5, #T_d52bd_row3_col6, #T_d52bd_row3_col7, #T_d52bd_row3_col8, #T_d52bd_row3_col9, #T_d52bd_row3_col10, #T_d52bd_row3_col11, #T_d52bd_row3_col12, #T_d52bd_row4_col0, #T_d52bd_row4_col1, #T_d52bd_row4_col2, #T_d52bd_row4_col3, #T_d52bd_row4_col4, #T_d52bd_row4_col5, #T_d52bd_row4_col6, #T_d52bd_row4_col7, #T_d52bd_row4_col8, #T_d52bd_row4_col9, #T_d52bd_row4_col10, #T_d52bd_row4_col11, #T_d52bd_row4_col12, #T_d52bd_row5_col0, #T_d52bd_row5_col1, #T_d52bd_row5_col2, #T_d52bd_row5_col3, #T_d52bd_row5_col4, #T_d52bd_row5_col5, #T_d52bd_row5_col6, #T_d52bd_row5_col7, #T_d52bd_row5_col8, #T_d52bd_row5_col9, #T_d52bd_row5_col10, #T_d52bd_row5_col11, #T_d52bd_row5_col12, #T_d52bd_row6_col0, #T_d52bd_row6_col1, #T_d52bd_row6_col2, #T_d52bd_row6_col3, #T_d52b
col6, #T_d52bd_row15_col7, #T_d52bd_row15_col8, #T_d52bd_row15_col9, #T_d52bd_row15_col10, #T_d52bd_row15_col11, #T_d52bd_row15_col12, #T_d52bd_row16_col0, #T_d52bd_row16_col1, #T_d52bd_row16_col2, #T_d52bd_row16_col3, #T_d52bd_row16_col4, #T_d52bd_row16_col5, #T_d52bd_row16_col6, #T_d52bd_row16_col7, #T_d52bd_row16_col8, #T_d52bd_row16_col9, #T_d52bd_row16_col10, #T_d52bd_row16_col11, #T_d52bd_row16_col12, #T_d52bd_row17_col0, #T_d52bd_row17_col1, #T_d52bd_row17_col2, #T_d52bd_row17_col3, #T_d52bd_row17_col4, #T_d52bd_row17_col5, #T_d52bd_row17_col6, #T_d52bd_row17_col7, #T_d52bd_row17_col8, #T_d52bd_row17_col9, #T_d52bd_row17_col10, #T_d52bd_row17_col11, #T_d52bd_row17_col12 {
#   background-color: red;
# }
# </style>
# <table id="T_d52bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d52bd_level0_col0" class="col_heading level0 col0" >sensitive_attribute</th>
#       <th id="T_d52bd_level0_col1" class="col_heading level0 col1" >group</th>
#       <th id="T_d52bd_level0_col2" class="col_heading level0 col2" >tp</th>
#       <th id="T_d52bd_level0_col3" class="col_heading level0 col3" >tn</th>
#       <th id="T_d52bd_level0_col4" class="col_heading level0 col4" >fp</th>
#       <th id="T_d52bd_level0_col5" class="col_heading level0 col5" >fn</th>
#       <th id="T_d52bd_level0_col6" class="col_heading level0 col6" >tpr</th>
#       <th id="T_d52bd_level0_col7" class="col_heading level0 col7" >tnr</th>
#       <th id="T_d52bd_level0_col8" class="col_heading level0 col8" >fpr</th>
#       <th id="T_d52bd_level0_col9" class="col_heading level0 col9" >fnr</th>
#       <th id="T_d52bd_level0_col10" class="col_heading level0 col10" >pr</th>
#       <th id="T_d52bd_level0_col11" class="col_heading level0 col11" >nr</th>
#       <th id="T_d52bd_level0_col12" class="col_heading level0 col12" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d52bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d52bd_row0_col0" class="data row0 col0" >ethnicity</td>
#       <td id="T_d52bd_row0_col1" class="data row0 col1" >AMERICAN INDIAN/ALASKA NATIVE</td>
#       <td id="T_d52bd_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_d52bd_row0_col3" class="data row0 col3" >24</td>
#       <td id="T_d52bd_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d52bd_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_d52bd_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_d52bd_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_d52bd_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_d52bd_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_d52bd_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_d52bd_row0_col11" class="data row0 col11" >1.000000</td>
#       <td id="T_d52bd_row0_col12" class="data row0 col12" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d52bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d52bd_row1_col0" class="data row1 col0" >ethnicity</td>
#       <td id="T_d52bd_row1_col1" class="data row1 col1" >ASIAN</td>
#       <td id="T_d52bd_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_d52bd_row1_col3" class="data row1 col3" >194</td>
#       <td id="T_d52bd_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_d52bd_row1_col5" class="data row1 col5" >13</td>
#       <td id="T_d52bd_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_d52bd_row1_col7" class="data row1 col7" >0.994872</td>
#       <td id="T_d52bd_row1_col8" class="data row1 col8" >0.005128</td>
#       <td id="T_d52bd_row1_col9" class="data row1 col9" >1.000000</td>
#       <td id="T_d52bd_row1_col10" class="data row1 col10" >0.004808</td>
#       <td id="T_d52bd_row1_col11" class="data row1 co
