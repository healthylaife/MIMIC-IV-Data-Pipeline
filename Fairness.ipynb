# %%
import os
import pickle
import pandas as pd
import numpy as np

# %% [markdown]
# ##### Path to outputdict file

# %%
output_dict_path = "outputDict" #path to output dict

# %%
os.path.isfile(output_dict_path)
# Out:
# True

# %% [markdown]
# ##### Load the file

# %%
output_dict = pickle.load(open(output_dict_path,"rb"))

# %%
output_dict
# Out:
#       Labels      Prob ethnicity gender  age
# 0          0  0.443426     WHITE      M   63
# 1          0  0.471146     WHITE      M   91
# 2          0  0.452288     WHITE      M   73
# 3          0  0.514837     WHITE      F   66
# 4          0  0.688411   UNKNOWN      M   78
# ...      ...       ...       ...    ...  ...
# 2995       0  0.398999     WHITE      M   31
# 2996       0  0.515015     WHITE      M   63
# 2997       0  0.444717     WHITE      F   63
# 2998       0  0.465339     WHITE      M   86
# 2999       0  0.525640     WHITE      M   92
#
# [3000 rows x 5 columns]

# %% [markdown]
# ##### Add predicted label using the probability

# %%
output_dict["Predicted"] = output_dict.apply(lambda row:row.Labels if row.Prob>=0.5 else 1-row.Labels, axis=1)

# %%
output_dict
# Out:
#       Labels      Prob ethnicity gender  age  Predicted
# 0          0  0.443426     WHITE      M   63          1
# 1          0  0.471146     WHITE      M   91          1
# 2          0  0.452288     WHITE      M   73          1
# 3          0  0.514837     WHITE      F   66          0
# 4          0  0.688411   UNKNOWN      M   78          0
# ...      ...       ...       ...    ...  ...        ...
# 2995       0  0.398999     WHITE      M   31          1
# 2996       0  0.515015     WHITE      M   63          0
# 2997       0  0.444717     WHITE      F   63          1
# 2998       0  0.465339     WHITE      M   86          1
# 2999       0  0.525640     WHITE      M   92          0
#
# [3000 rows x 6 columns]

# %% [markdown]
# ##### Bin age

# %%
output_dict["age_binned"] = output_dict.age.apply(lambda x:"{}-{}".format((x//10)*10,(x//10 + 1)*10))

# %% [markdown]
# ##### List of sensitive columns

# %%
sensitive_columns = ["ethnicity", "gender", "age_binned"]

# %% [markdown]
# ##### Function to compute the Confusion Matrix parameters

# %%
def get_cm_parameters(gt, pred):
    zipped_gt_pred = list(zip(gt,pred))
    tp = len([pair for pair in zipped_gt_pred if pair == (1,1)])
    tn = len([pair for pair in zipped_gt_pred if pair == (0,0)])
    fp = len([pair for pair in zipped_gt_pred if pair == (0,1)])
    fn = len([pair for pair in zipped_gt_pred if pair == (1,0)])
    
    try:
        tpr = tp/(tp + fn)
    except ZeroDivisionError:
        tpr = None
    try:
        tnr = tn/(tn + fp)
    except ZeroDivisionError:
        tnr = None
    try:
        fpr = fp/(fp + tn)
    except ZeroDivisionError:
        fpr = None
    try:
        fnr = fn/(fn + tp)
    except ZeroDivisionError:
        fnr = None
    try:
        acc = (tp+tn)/(len(zipped_gt_pred))
    except ZeroDivisionError:
        acc = None
    
    return tp, tn, fp, fn, tpr, tnr, fpr, fnr, acc

# %% [markdown]
# ##### Generate fairness report

# %%
report_list = []
for sens_col in sensitive_columns:
    for group, aggregate in output_dict.groupby(sens_col):
        tmp_dct = {"sensitive_attribute": sens_col}
        tp, tn, fp, fn, tpr, tnr, fpr, fnr, acc = get_cm_parameters(list(aggregate.Labels), list(aggregate.Predicted))
        tmp_dct.update(dict(
            group=group,tp=tp, tn=tn, fp=fp, fn=fn, tpr=tpr, tnr=tnr, fpr= fpr, fnr=fnr, accuracy=acc    
            )
        )
        report_list.append(tmp_dct)

# %%
report = pd.DataFrame(report_list)
report_groups = {c:i for i,c in enumerate(report.sensitive_attribute.unique())}

# %%
def highlight(s):
    colors = [['background-color: yellow'], ['background-color: green'], ['background-color: red']]
    return colors[report_groups[s.sensitive_attribute]%len(colors)] * len(s)

# %%
try:
    import jinja2
    display(report.style.apply(highlight, axis=1))
except ImportError:
    display(report)
# Out:
# <style type="text/css">
# #T_0bc34_row0_col0, #T_0bc34_row0_col1, #T_0bc34_row0_col2, #T_0bc34_row0_col3, #T_0bc34_row0_col4, #T_0bc34_row0_col5, #T_0bc34_row0_col6, #T_0bc34_row0_col7, #T_0bc34_row0_col8, #T_0bc34_row0_col9, #T_0bc34_row0_col10, #T_0bc34_row1_col0, #T_0bc34_row1_col1, #T_0bc34_row1_col2, #T_0bc34_row1_col3, #T_0bc34_row1_col4, #T_0bc34_row1_col5, #T_0bc34_row1_col6, #T_0bc34_row1_col7, #T_0bc34_row1_col8, #T_0bc34_row1_col9, #T_0bc34_row1_col10, #T_0bc34_row2_col0, #T_0bc34_row2_col1, #T_0bc34_row2_col2, #T_0bc34_row2_col3, #T_0bc34_row2_col4, #T_0bc34_row2_col5, #T_0bc34_row2_col6, #T_0bc34_row2_col7, #T_0bc34_row2_col8, #T_0bc34_row2_col9, #T_0bc34_row2_col10, #T_0bc34_row3_col0, #T_0bc34_row3_col1, #T_0bc34_row3_col2, #T_0bc34_row3_col3, #T_0bc34_row3_col4, #T_0bc34_row3_col5, #T_0bc34_row3_col6, #T_0bc34_row3_col7, #T_0bc34_row3_col8, #T_0bc34_row3_col9, #T_0bc34_row3_col10, #T_0bc34_row4_col0, #T_0bc34_row4_col1, #T_0bc34_row4_col2, #T_0bc34_row4_col3, #T_0bc34_row4_col4, #T_0bc34_row4_col5, #T_0bc34_row4_col6, #T_0bc34_row4_col7, #T_0bc34_row4_col8, #T_0bc34_row4_col9, #T_0bc34_row4_col10, #T_0bc34_row5_col0, #T_0bc34_row5_col1, #T_0bc34_row5_col2, #T_0bc34_row5_col3, #T_0bc34_row5_col4, #T_0bc34_row5_col5, #T_0bc34_row5_col6, #T_0bc34_row5_col7, #T_0bc34_row5_col8, #T_0bc34_row5_col9, #T_0bc34_row5_col10, #T_0bc34_row6_col0, #T_0bc34_row6_col1, #T_0bc34_row6_col2, #T_0bc34_row6_col3, #T_0bc34_row6_col4, #T_0bc34_row6_col5, #T_0bc34_row6_col6, #T_0bc34_row6_col7, #T_0bc34_row6_col8, #T_0bc34_row6_col9, #T_0bc34_row6_col10, #T_0bc34_row7_col0, #T_0bc34_row7_col1, #T_0bc34_row7_col2, #T_0bc34_row7_col3, #T_0bc34_row7_col4, #T_0bc34_row7_col5, #T_0bc34_row7_col6, #T_0bc34_row7_col7, #T_0bc34_row7_col8, #T_0bc34_row7_col9, #T_0bc34_row7_col10 {
#   background-color: yellow;
# }
